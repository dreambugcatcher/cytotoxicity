# %%
from rdkit.Chem import Descriptors, MolFromSmiles
from sklearn.preprocessing import FunctionTransformer, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, RepeatedKFold
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, balanced_accuracy_score, matthews_corrcoef, roc_auc_score, f1_score, confusion_matrix
from pandas import DataFrame, concat
from pickle import load

# %%
#создаем словарь из дескприторов структуры
ConstDescriptors = {"HeavyAtomCount" : Descriptors.HeavyAtomCount,
                       "NHOHCount" : Descriptors.NHOHCount,
                       "NOCount" : Descriptors.NOCount,
                       "NumHAcceptors" : Descriptors.NumHAcceptors,
                       "NumHDonors" : Descriptors.NumHDonors,
                       "NumHeteroatoms" : Descriptors.NumHeteroatoms,
                       "NumRotatableBonds" : Descriptors.NumRotatableBonds,
                       "NumValenceElectrons" : Descriptors.NumValenceElectrons,
                       "NumAromaticRings" : Descriptors.NumAromaticRings,
                       "NumAliphaticHeterocycles" : Descriptors.NumAliphaticHeterocycles,
                       "RingCount" : Descriptors.RingCount}

#создаем словарь из физико-химических дескрипторов                            
PhisChemDescriptors = {"MW" : Descriptors.MolWt,
                          "LogP" : Descriptors.MolLogP,
                          "MR" : Descriptors.MolMR,
                          "TPSA" : Descriptors.TPSA}

#объединяем все дескрипторы в один словарь
descriptors = {}
descriptors.update(ConstDescriptors)
descriptors.update(PhisChemDescriptors)
print(len(descriptors), "количество дескрипторов в словаре")


#функция для генерации дескрипторов из молекул
def mol_dsc_calc(mols):
    
    return DataFrame({k: f(m) for k, f in descriptors.items()} 
             for m in mols)


with open('../data/classifier/modeling_data.pickle', 'rb') as file:
    data = load(file)
#оформляем sklearn трансформер для использования в конвеерном моделировании (sklearn Pipeline)
descriptors_transformer = FunctionTransformer(mol_dsc_calc, validate=False)
# Out:
# 15 количество дескрипторов в словаре

# %%
molecules = [
    MolFromSmiles(mol) for mol in data['SMILES']
]

# %%
X = descriptors_transformer.transform(molecules)
Y = data['Activity']
XY = concat((X, Y), axis=1)

# %%
XY
# Out:
#        HeavyAtomCount  NHOHCount  NOCount  NumHAcceptors  NumHDonors  \
# 0                  32          0        8              7           0
# 1                  23          0        5              4           0
# 2                  23          1        5              4           1
# 3                  24          1        4              3           1
# 4                  17          3        3              2           3
# ...               ...        ...      ...            ...         ...
# 75924              24          1        5              4           1
# 75925              28          1        6              5           1
# 75926              32          3        9              7           2
# 75927              22          1        6              5           1
# 75928              27          1        7              7           1
#
#        NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# 0                   8                  5                  164
# 1                   6                  3                  122
# 2                   6                  2                  126
# 3                   5                  3                  124
# 4                   3                  0                   88
# ...               ...                ...                  ...
# 75924               6                  4                  122
# 75925               6                  7                  140
# 75926               9                  7                  168
# 75927               7                  2                  114
# 75928               9                  5                  140
#
#        NumAromaticRings  NumAliphaticHeterocycles  RingCount       MW  \
# 0                     3                         2          5  434.448
# 1                     1                         2          4  319.332
# 2                     1                         2          3  323.364
# 3                     2                         2          4  327.355
# 4                     2                         1          4  228.295
# ...                 ...                       ...        ...      ...
# 75924                 3                         0          4  340.814
# 75925                 4                         0          4  373.412
# 75926                 3                         1          4  436.516
# 75927                 2                         1          3  317.370
# 75928                 3                         1          4  402.501
#
#           LogP        MR    TPSA  Activity
# 0      3.48760  113.2495   91.10         1
# 1      2.05930   78.1170   55.84         1
# 2      2.73460   81.6418   59.00         0
# 3      2.32120   85.9918   49.77         1
# 4      1.53040   67.1582   48.05         1
# ...        ...       ...     ...       ...
# 75924  3.42850   94.0122   59.81         1
# 75925  3.80440  106.2408   77.24         1
# 75926  2.37562  119.8996  119.28         1
# 75927  2.05462   83.2152   71.53         1
# 75928  2.73350  103.2105   84.42         1
#
# [75929 rows x 16 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15)

# %%
scaler_x = StandardScaler().fit(x_train)
x_train_scal = scaler_x.transform(x_train)
x_test_scal = scaler_x.transform(x_test)

# %%
cv = RepeatedKFold(n_splits=5, n_repeats=5, random_state=42)
c = [1, 10, 50]
g = [0.1, 0.01, 0.001]
cf = [0, 0.5, 1]
pg = [
    {
        'kernel': ['poly'],
        'gamma': g,
        'C': c, 
        'degree': [2, 3],
        'coef0' : cf,
    },
    {
        'kernel': ['sigmoid'],
        'gamma': g,
        'C' : c,
        'coef0' : cf,
    },
    {
        'kernel':  ['rbf'],
        'gamma': g,
        'C' : c,
    }]
grid = GridSearchCV(SVC(verbose=3, shrinking=False), pg, cv=cv, verbose=3, refit='balanced_accuracy', scoring=('f1', 'balanced_accuracy'), n_jobs=12)
grid.fit(x_train_scal, y_train)
# Out:
# Fitting 25 folds for each of 90 candidates, totalling 2250 fits
# .....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 91184
# obj = -10513.998039, rho = 1.000170
# nSV = 13433, nBSV = 9217
# Total nSV = 13433
# *
# optimization finished, #iter = 90532
# obj = -10483.996122, rho = 1.000262
# nSV = 13269, nBSV = 9033
# Total nSV = 13269
# .......................................*
# optimization finished, #iter = 101029
# obj = -10703.995313, rho = 1.000190
# nSV = 13562, nBSV = 9309
# Total nSV = 13562
# .......................*
# optimization finished, #iter = 103567
# obj = -10619.996702, rho = 1.000205
# nSV = 13408, nBSV = 9303
# Total nSV = 13408
# ..................................*
# optimization finished, #iter = 112165
# obj = -10457.996239, rho = 1.000207
# nSV = 13389, nBSV = 9072
# Total nSV = 13389
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 95766
# obj = -10479.995849, rho = 1.000209
# nSV = 13467, nBSV = 9189
# Total nSV = 13467
# ......................................................*
# optimization finished, #iter = 84472
# obj = -10497.997296, rho = 1.000190
# nSV = 13228, nBSV = 9131
# Total nSV = 13228
# ..............*
# optimization finished, #iter = 95850
# obj = -10661.996359, rho = 1.000233
# nSV = 13674, nBSV = 9216
# Total nSV = 13674
# ...................................*
# optimization finished, #iter = 110517
# obj = -10565.995813, rho = 1.000191
# nSV = 13516, nBSV = 9247
# Total nSV = 13516
# ................*
# optimization finished, #iter = 98712
# obj = -10609.997071, rho = 1.000196
# nSV = 13469, nBSV = 9340
# Total nSV = 13469
# ..............*
# optimization finished, #iter = 101738
# obj = -10563.997112, rho = 1.000210
# nSV = 13521, nBSV = 9245
# Total nSV = 13521
# ...............*
# optimization finished, #iter = 101887
# obj = -10527.995741, rho = 1.000222
# nSV = 13482, nBSV = 9151
# Total nSV = 13482
# .....*
# optimization finished, #iter = 106106
# obj = -10521.996233, rho = 1.000209
# nSV = 13364, nBSV = 9150
# Total nSV = 13364
# ............*
# optimization finished, #iter = 105569
# .obj = -10503.996918, rho = 1.000230
# nSV = 13447, nBSV = 9139
# Total nSV = 13447
# ........................................................*
# optimization finished, #iter = 110084
# .obj = -10547.995138, rho = 1.000180
# nSV = 13642, nBSV = 9100
# Total nSV = 13642
# .........................................................*
# optimization finished, #iter = 111244
# obj = -10625.995921, rho = 1.000212
# nSV = 13712, nBSV = 9151
# Total nSV = 13712
# ..........................*
# optimization finished, #iter = 121472
# obj = -10627.996120, rho = 1.000200
# nSV = 13646, nBSV = 9186
# Total nSV = 13646
# ...........................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 107242
# obj = -10659.994969, rho = 1.000209
# nSV = 13502, nBSV = 9235
# Total nSV = 13502
# .................*
# optimization finished, #iter = 98159
# obj = -10561.996452, rho = 1.000205
# nSV = 13533, nBSV = 9253
# Total nSV = 13533
# .................*
# optimization finished, #iter = 99933
# obj = -10589.996333, rho = 1.000149
# nSV = 13542, nBSV = 9232
# Total nSV = 13542
# .........*
# optimization finished, #iter = 96376
# obj = -10475.996105, rho = 1.000215
# nSV = 13347, nBSV = 9114
# Total nSV = 13347
# ..............*
# optimization finished, #iter = 94362
# obj = -10559.995504, rho = 1.000215
# nSV = 13336, nBSV = 9239
# Total nSV = 13336
# ...............*
# optimization finished, #iter = 9005
# .obj = -10457.987718, rho = 1.000232
# nSV = 11204, nBSV = 9895
# Total nSV = 11204
# ...............................*
# optimization finished, #iter = 9536
# obj = -10627.986422, rho = 1.000229
# nSV = 11435, nBSV = 10028
# Total nSV = 11435
# ............*
# optimization finished, #iter = 9167
# obj = -10609.987317, rho = 1.000184
# nSV = 11351, nBSV = 10034
# Total nSV = 11351
# .............*
# optimization finished, #iter = 8826
# obj = -10513.987584, rho = 1.000235
# nSV = 11222, nBSV = 9956
# Total nSV = 11222
# ..........*
# optimization finished, #iter = 8889
# obj = -10483.985885, rho = 1.000191
# nSV = 11182, nBSV = 9933
# Total nSV = 11182
# ......*
# optimization finished, #iter = 9100
# obj = -10563.987132, rho = 1.000195
# nSV = 11337, nBSV = 10028
# Total nSV = 11337
# ..........*
# optimization finished, #iter = 8810
# obj = -10547.987174, rho = 1.000260
# nSV = 11287, nBSV = 9995
# Total nSV = 11287
# .......*
# optimization finished, #iter = 9173
# obj = -10527.989121, rho = 1.000190
# nSV = 11312, nBSV = 9981
# Total nSV = 11312
# ..*
# optimization finished, #iter = 9301
# obj = -10703.986219, rho = 1.000157
# nSV = 11511, nBSV = 10114
# Total nSV = 11511
# ................................*
# optimization finished, #iter = 8971
# obj = -10619.987992, rho = 1.000200
# nSV = 11383, nBSV = 10053
# Total nSV = 11383
# ..........*
# optimization finished, #iter = 9134
# obj = -10503.988007, rho = 1.000177
# nSV = 11253, nBSV = 9915
# Total nSV = 11253
# ..................*
# optimization finished, #iter = 9141
# obj = -10661.989188, rho = 1.000233
# nSV = 11381, nBSV = 10070
# Total nSV = 11381
# ........*
# optimization finished, #iter = 9219
# obj = -10565.988646, rho = 1.000181
# nSV = 11307, nBSV = 10056
# Total nSV = 11307
# ..............*
# optimization finished, #iter = 8995
# obj = -10521.988278, rho = 1.000202
# nSV = 11291, nBSV = 9968
# Total nSV = 11291
# ...................................*
# optimization finished, #iter = 9481
# obj = -10561.989503, rho = 1.000178
# nSV = 11351, nBSV = 9964
# Total nSV = 11351
# ..............*
# optimization finished, #iter = 8881
# obj = -10589.988418, rho = 1.000218
# nSV = 11307, nBSV = 9992
# Total nSV = 11307
# ...........*
# optimization finished, #iter = 8427
# obj = -10475.988021, rho = 1.000208
# nSV = 11104, nBSV = 9962
# Total nSV = 11104
# .........*
# optimization finished, #iter = 8696
# obj = -10617.985402, rho = 1.000229
# nSV = 11334, nBSV = 10042
# Total nSV = 11334
# ...............*
# optimization finished, #iter = 9646
# obj = -10573.988779, rho = 1.000155
# nSV = 11394, nBSV = 9991
# Total nSV = 11394
# .............................*
# optimization finished, #iter = 9010
# obj = -10625.987657, rho = 1.000194
# nSV = 11376, nBSV = 10053
# Total nSV = 11376
# ............*
# optimization finished, #iter = 8669
# obj = -10559.987333, rho = 1.000219
# nSV = 11275, nBSV = 10024
# Total nSV = 11275
# ..........*
# optimization finished, #iter = 5956
# obj = -10457.983774, rho = 1.000187
# nSV = 10480, nBSV = 10437
# Total nSV = 10480
# *
# optimization finished, #iter = 8972
# obj = -10603.984834, rho = 1.000235
# nSV = 11302, nBSV = 10042
# Total nSV = 11302
# .......*
# optimization finished, #iter = 5955
# obj = -10513.978740, rho = 1.000243
# nSV = 10530, nBSV = 10498
# Total nSV = 10530
# ..............*
# optimization finished, #iter = 9219
# .obj = -10479.989981, rho = 1.000225
# nSV = 11231, nBSV = 9904
# Total nSV = 11231
# ....*
# optimization finished, #iter = 6155
# obj = -10703.985509, rho = 1.000222
# nSV = 10724, nBSV = 10686
# Total nSV = 10724
# ............................*
# optimization finished, #iter = 8529
# obj = -10497.985821, rho = 1.000250
# nSV = 11213, nBSV = 9955
# Total nSV = 11213
# *
# optimization finished, #iter = 6084
# obj = -10627.982440, rho = 1.000244
# nSV = 10652, nBSV = 10604
# Total nSV = 10652
# ....*
# optimization finished, #iter = 9250
# obj = -10659.986430, rho = 1.000176
# nSV = 11372, nBSV = 10086
# Total nSV = 11372
# ..................*
# optimization finished, #iter = 6011
# obj = -10609.975615, rho = 1.000281
# nSV = 10623, nBSV = 10599
# Total nSV = 10623
# .*
# optimization finished, #iter = 5995
# obj = -10483.981813, rho = 1.000328
# nSV = 10499, nBSV = 10471
# Total nSV = 10499
# ......*
# optimization finished, #iter = 6067
# obj = -10563.985047, rho = 1.000085
# nSV = 10591, nBSV = 10538
# Total nSV = 10591
# .....*
# optimization finished, #iter = 6035
# obj = -10625.979398, rho = 1.000291
# nSV = 10639, nBSV = 10613
# Total nSV = 10639
# ....................................*
# optimization finished, #iter = 6029
# .obj = -10619.975023, rho = 1.000441
# nSV = 10633, nBSV = 10608
# Total nSV = 10633
# .......................*
# optimization finished, #iter = 6135
# obj = -10661.986693, rho = 1.000237
# nSV = 10677, nBSV = 10645
# Total nSV = 10677
# *
# optimization finished, #iter = 6096
# obj = -10565.986441, rho = 1.000309
# nSV = 10595, nBSV = 10537
# Total nSV = 10595
# ...*
# optimization finished, #iter = 5967
# obj = -10521.976219, rho = 1.000345
# nSV = 10539, nBSV = 10504
# Total nSV = 10539
# ..*
# optimization finished, #iter = 5970
# obj = -10497.979294, rho = 1.000380
# nSV = 10509, nBSV = 10486
# Total nSV = 10509
# ..................................*
# optimization finished, #iter = 6066
# obj = -10659.974280, rho = 1.000369
# nSV = 10670, nBSV = 10649
# Total nSV = 10670
# ....................*
# optimization finished, #iter = 6012
# obj = -10561.984168, rho = 1.000290
# nSV = 10581, nBSV = 10545
# Total nSV = 10581
# .*
# optimization finished, #iter = 6022
# obj = -10589.981006, rho = 1.000250
# nSV = 10605, nBSV = 10576
# Total nSV = 10605
# ...*
# optimization finished, #iter = 6039
# obj = -10527.983865, rho = 1.000237
# nSV = 10550, nBSV = 10508
# Total nSV = 10550
# ...*
# optimization finished, #iter = 5922
# obj = -10475.975621, rho = 1.000230
# nSV = 10490, nBSV = 10462
# Total nSV = 10490
# .........*
# optimization finished, #iter = 6020
# obj = -10617.976609, rho = 1.000153
# nSV = 10632, nBSV = 10604
# Total nSV = 10632
# ...........*
# optimization finished, #iter = 5966
# obj = -10547.980632, rho = 1.000350
# nSV = 10561, nBSV = 10536
# Total nSV = 10561
# ......................*
# optimization finished, #iter = 5963
# obj = -10573.975524, rho = 1.000262
# nSV = 10585, nBSV = 10563
# Total nSV = 10585
# ...........................*
# optimization finished, #iter = 5975
# obj = -10559.976618, rho = 1.000306
# nSV = 10574, nBSV = 10548
# Total nSV = 10574
# .*
# optimization finished, #iter = 6115
# obj = -10603.985732, rho = 1.000274
# nSV = 10628, nBSV = 10581
# Total nSV = 10628
# .....*
# optimization finished, #iter = 5963
# .obj = -10479.985827, rho = 1.000220
# nSV = 10499, nBSV = 10462
# Total nSV = 10499
# .*
# optimization finished, #iter = 6008
# obj = -10503.987241, rho = 1.000244
# nSV = 10524, nBSV = 10483
# Total nSV = 10524
# ....................*
# optimization finished, #iter = 102859
# obj = -10617.995334, rho = 1.000218
# nSV = 13616, nBSV = 9327
# Total nSV = 13616
# ......................*
# optimization finished, #iter = 106771
# obj = -10573.996943, rho = 1.000230
# nSV = 13430, nBSV = 9160
# Total nSV = 13430
# ..........................................................................................................................................*
# optimization finished, #iter = 104049
# obj = -10603.996503, rho = 1.000200
# nSV = 13592, nBSV = 9178
# Total nSV = 13592
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# optimization finished, #iter = 1062474
# .obj = -9766.862234, rho = 1.155576
# nSV = 10009, nBSV = 9680
# Total nSV = 10009
# ..................................................................................................................................................................................................................*
# optimization finished, #iter = 1073743
# .obj = -9708.494163, rho = 1.160538
# nSV = 9949, nBSV = 9628
# Total nSV = 9949
# ...............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1201828
# .obj = -9641.704695, rho = 1.158409
# nSV = 9895, nBSV = 9558
# Total nSV = 9895
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1306845
# obj = -9684.238197, rho = 1.149534
# nSV = 9924, nBSV = 9589
# Total nSV = 9924
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1506405
# obj = -9559.859946, rho = 1.156606
# nSV = 9806, nBSV = 9473
# Total nSV = 9806
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# optimization finished, #iter = 1130759
# .obj = -9710.153955, rho = 1.160264
# nSV = 9943, nBSV = 9627
# Total nSV = 9943
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1369964
# .obj = -9621.599048, rho = 1.159285
# nSV = 9874, nBSV = 9544
# Total nSV = 9874
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1573230
# obj = -9658.491177, rho = 1.161426
# nSV = 9901, nBSV = 9575
# Total nSV = 9901
# ................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1174850
# ..obj = -9629.404170, rho = 1.150137
# nSV = 9868, nBSV = 9537
# Total nSV = 9868
# ...............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1139483
# obj = -9742.754881, rho = 1.152895
# nSV = 9975, nBSV = 9650
# Total nSV = 9975
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1698601
# obj = -9634.640823, rho = 1.150571
# nSV = 9876, nBSV = 9552
# Total nSV = 9876
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1437728
# .obj = -9634.051238, rho = 1.149621
# nSV = 9882, nBSV = 9534
# Total nSV = 9882
# .....................*
# optimization finished, #iter = 1288983
# ..obj = -9725.998518, rho = 1.159136
# nSV = 9972, nBSV = 9645
# Total nSV = 9972
# .............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1369662
# ..obj = -9619.700349, rho = 1.165739
# nSV = 9863, nBSV = 9536
# Total nSV = 9863
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1374332
# .obj = -9722.061859, rho = 1.156534
# .nSV = 9957, nBSV = 9625
# Total nSV = 9957
# ...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1424508
# .obj = -9580.408650, rho = 1.161912
# nSV = 9822, nBSV = 9481
# Total nSV = 9822
# ................................*
# optimization finished, #iter = 1279569
# obj = -9662.588961, rho = 1.169176
# nSV = 9921, nBSV = 9589
# Total nSV = 9921
# ...............................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1447511
# .obj = -9627.236043, rho = 1.148800
# nSV = 9862, nBSV = 9541
# Total nSV = 9862
# ................................................................................................................................................................................*
# optimization finished, #iter = 1068969
# obj = -9670.900159, rho = 1.160171
# nSV = 9914, nBSV = 9578
# Total nSV = 9914
# ......................................................................................................*
# optimization finished, #iter = 10691
# obj = -10368.104612, rho = 1.037297
# nSV = 10534, nBSV = 10462
# Total nSV = 10534
# .......................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 10852
# .obj = -10447.751111, rho = 1.038198
# nSV = 10613, nBSV = 10545
# Total nSV = 10613
# .........................................................................................................................*
# optimization finished, #iter = 11154
# obj = -10313.514830, rho = 1.039035
# nSV = 10486, nBSV = 10411
# Total nSV = 10486
# ......................................................................................................................................................................*
# optimization finished, #iter = 11011
# ..obj = -10307.117207, rho = 1.038086
# nSV = 10464, nBSV = 10395
# Total nSV = 10464
# ...........................................................................................................................................................................................................*
# optimization finished, #iter = 10605
# .obj = -10403.894887, rho = 1.037809
# nSV = 10568, nBSV = 10499
# Total nSV = 10568
# ..............................*
# optimization finished, #iter = 12121
# ..obj = -10389.207019, rho = 1.034659
# nSV = 10545, nBSV = 10455
# Total nSV = 10545
# ..............................................................................................*
# optimization finished, #iter = 11648
# obj = -10421.886243, rho = 1.034680
# nSV = 10572, nBSV = 10499
# Total nSV = 10572
# ...........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 975148
# obj = -9600.551287, rho = 1.157609
# nSV = 9849, nBSV = 9505
# Total nSV = 9849
# ..........................................................*
# optimization finished, #iter = 11060
# obj = -10347.939267, rho = 1.036344
# nSV = 10506, nBSV = 10428
# Total nSV = 10506
# ...........................*
# optimization finished, #iter = 11306
# obj = -10459.544830, rho = 1.036683
# nSV = 10627, nBSV = 10539
# Total nSV = 10627
# ............................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 11090
# obj = -10496.023943, rho = 1.038817
# nSV = 10660, nBSV = 10593
# Total nSV = 10660
# .*
# optimization finished, #iter = 11859
# ..*
# optimization finished, #iter = 1206340
# obj = -10467.084154, rho = 1.039046
# nSV = 10635, nBSV = 10561
# Total nSV = 10635
# obj = -9735.651503, rho = 1.156113
# nSV = 9983, nBSV = 9639
# Total nSV = 9983
# ...........................................................*
# optimization finished, #iter = 10385
# .obj = -10540.202755, rho = 1.037900
# nSV = 10713, nBSV = 10635
# Total nSV = 10713
# ..........................................................................................................................*
# optimization finished, #iter = 11218
# obj = -10413.492495, rho = 1.037953
# nSV = 10578, nBSV = 10503
# Total nSV = 10578
# ...........................*
# optimization finished, #iter = 10648
# obj = -10374.140270, rho = 1.037211
# nSV = 10541, nBSV = 10461
# Total nSV = 10541
# ................................................................................*
# optimization finished, #iter = 11504
# obj = -10485.671892, rho = 1.037104
# nSV = 10653, nBSV = 10573
# Total nSV = 10653
# .....................................................................................................................................................................*
# optimization finished, #iter = 11749
# obj = -10356.687784, rho = 1.037649
# nSV = 10516, nBSV = 10446
# Total nSV = 10516
# .............................................................................................................*
# optimization finished, #iter = 1110784
# obj = -9648.382777, rho = 1.162742
# nSV = 9903, nBSV = 9566
# Total nSV = 9903
# ..............................*
# optimization finished, #iter = 11276
# obj = -10334.305012, rho = 1.038193
# nSV = 10498, nBSV = 10418
# Total nSV = 10498
# .......*
# optimization finished, #iter = 10654
# obj = -10458.129857, rho = 1.037588
# nSV = 10629, nBSV = 10555
# Total nSV = 10629
# .............*
# optimization finished, #iter = 10612
# ..obj = -10470.117429, rho = 1.040148
# nSV = 10653, nBSV = 10578
# Total nSV = 10653
# ..........................................................*
# optimization finished, #iter = 11035
# obj = -10407.576414, rho = 1.038761
# nSV = 10574, nBSV = 10502
# Total nSV = 10574
# .............................................................................................................

# %%
y_pred = grid.predict(x_test_scal)

# %%
grid.best_estimator_

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel().tolist()
precision = tp / (tp + fp)
recall = tp / (tp + fn)

# %%
print(f'ACC = {accuracy_score(y_test, y_pred):.3f}')
print(f'BA = {balanced_accuracy_score(y_test, y_pred):.3f}')
print(f'MCC = {matthews_corrcoef(y_test, y_pred):.3f}')
print(f'ROC AUC = {roc_auc_score(y_test, y_pred):.3f}')
print(f'F1 = {f1_score(y_test, y_pred):.3f}')
print(f'Precision = {precision:.3f}')
print(f'Recall = {recall:.3f}')

# %%
grid.get_params()
